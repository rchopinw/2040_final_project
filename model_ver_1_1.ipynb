# %%
import tensorflow as tf
import numpy as np

# %%
class HyperParams:
    num_words = 92
    num_docs = 50
    sequence_len = 10
    batch_size = 16
    vocab_size = 252911
    embedded_size = 256
    num_units_bi_gru_1 = 128
    num_units_main_gru = 512
    num_units_main_gru_2 = 128
    num_units_post_dense_1 = 300
    num_units_post_dense_2 = 64
    num_output = 1
    auxiliary_x = 6

    lr = 1e-05
    validation_steps = 2
    auto_tune = tf.data.experimental.AUTOTUNE
    opt = tf.keras.optimizers.Adam(lr)
    loss = tf.keras.losses.MeanSquaredError()
    epochs = 40
    metrics = ['mean_absolute_error', 'mean_squared_error', 'mean_squared_logarithmic_error']
    es = tf.keras.callbacks.EarlyStopping(monitor='val_loss',
                                          mode='min',
                                          patience=10)
    r = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss',
                                             factor=0.8,
                                             patience=2,
                                             verbose=1,
                                             mode='auto',
                                             epsilon=0.0001,
                                             cooldown=5,
                                             min_lr=0.00001)


def save_obj(obj, name):
    """
    :param obj:
    :param name:
    :return:
    """
    with open(name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)


def load_obj(name):
    """
    :param name:
    :return:
    """
    with open(name + '.pkl', 'rb') as f:
        return pickle.load(f)


def tri_attention_rnn_model(plot_model=True,
                            summary_model=True):
    word_input = tf.keras.Input(shape=HyperParams.num_words,
                                dtype='int64',
                                name='word_input')

    # Embedding layer
    word_embedding = tf.keras.layers.Embedding(input_dim=HyperParams.vocab_size,
                                               output_dim=HyperParams.embedded_size)(word_input)
    bi_gru_1 = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(HyperParams.num_units_bi_gru_1,
                                                                 return_sequences=True))(word_embedding)
    # the first attention layer to capture the word-level attentions
    attention_dense_1 = tf.keras.layers.Dense(HyperParams.num_units_bi_gru_1 * 2,
                                              activation='tanh')(bi_gru_1)
    attention_softmax_1 = tf.keras.layers.Activation('softmax')(attention_dense_1)
    attention_mul_1 = tf.keras.layers.multiply([attention_softmax_1, bi_gru_1])
    vec_sum_1 = tf.keras.layers.Lambda(lambda x: tf.keras.backend.sum(x, axis=1))(attention_mul_1)
    word_level_model = tf.keras.Model(inputs=word_input,
                                      outputs=vec_sum_1)

    doc_input = tf.keras.Input(shape=(HyperParams.num_docs, HyperParams.num_words),
                               dtype='int64',
                               name='doc_input')
    post_bi_gru_1 = tf.keras.layers.TimeDistributed(word_level_model)(doc_input)

    # the second attention layer to capture the news-level attentions
    attention_dense_2 = tf.keras.layers.Dense(HyperParams.num_units_bi_gru_1 * 2,
                                              activation='tanh')(post_bi_gru_1)
    attention_softmax_2 = tf.keras.layers.Activation('softmax')(attention_dense_2)
    attention_mul_2 = tf.keras.layers.multiply([attention_softmax_2, post_bi_gru_1])
    vec_sum_2 = tf.keras.layers.Lambda(lambda x: tf.keras.backend.sum(x, axis=1))(attention_mul_2)
    doc_level_model = tf.keras.Model(inputs=doc_input, outputs=vec_sum_2)

    seq_input = tf.keras.Input(shape=(HyperParams.sequence_len, HyperParams.num_docs, HyperParams.num_words),
                               dtype='int64',
                               name='seq_input')

    # Incorporating the auxiliary variables
    auxiliary_input = tf.keras.Input(shape=(HyperParams.sequence_len, HyperParams.auxiliary_x),
                                     dtype='float32',
                                     name='auxiliary_input')
    pre_main_gru = tf.keras.layers.TimeDistributed(doc_level_model)(seq_input)
    pre_main_gru_concat = tf.keras.layers.concatenate([pre_main_gru, auxiliary_input], axis=-1)
    main_gru = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(HyperParams.num_units_main_gru,
                                                                 return_sequences=True))(pre_main_gru_concat)
    main_gru_2 = tf.keras.layers.Bidirectional(tf.keras.layers.GRU(HyperParams.num_units_main_gru_2,
                                                                   return_sequences=True))(main_gru)

    # the third attention layer to capture the time-level attentions
    attention_dense_3 = tf.keras.layers.Dense(HyperParams.num_units_main_gru_2 * 2,
                                              activation='tanh')(main_gru_2)
    attention_softmax_3 = tf.keras.layers.Activation('softmax')(attention_dense_3)
    attention_mul_3 = tf.keras.layers.multiply([attention_softmax_3, main_gru_2])
    vec_sum_3 = tf.keras.layers.Lambda(lambda x: tf.keras.backend.sum(x, axis=1))(attention_mul_3)

    # Passing through multiple FC layers
    main_dense_1 = tf.keras.layers.Dense(HyperParams.num_units_post_dense_1,
                                         activation='tanh',
                                         kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0.00001,
                                                                                        l2=0.00001))(vec_sum_3)
    main_dropout_1 = tf.keras.layers.Dropout(0.1)(main_dense_1)
    main_dense_2 = tf.keras.layers.Dense(HyperParams.num_units_post_dense_2,
                                         activation='tanh',
                                         kernel_regularizer=tf.keras.regularizers.l1_l2(l1=0.00001,
                                                                                        l2=0.00001))(main_dropout_1)
    main_dropout_2 = tf.keras.layers.Dropout(0.1)(main_dense_2)
    output = tf.keras.layers.Dense(HyperParams.num_output,
                                   activation=None)(main_dropout_2)

    model = tf.keras.Model(inputs=[seq_input, auxiliary_input], outputs=output)

    if plot_model:
        tf.keras.utils.plot_model(model, show_shapes=True, expand_nested=True)
    if summary_model:
        print(model.summary())
    return model
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.

# %%
m1 = tri_attention_rnn_model()
m1.compile(optimizer=HyperParams.opt, loss=HyperParams.loss, metrics=HyperParams.metrics)
tf.keras.utils.plot_model(m1, show_shapes=True, expand_nested=True)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# seq_input (InputLayer)          [(None, 10, 50, 92)] 0
# __________________________________________________________________________________________________
# time_distributed_1 (TimeDistrib (None, 10, 256)      65173248    seq_input[0][0]
# __________________________________________________________________________________________________
# auxiliary_input (InputLayer)    [(None, 10, 6)]      0
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 10, 262)      0           time_distributed_1[0][0]
#                                                                  auxiliary_input[0][0]
# __________________________________________________________________________________________________
# bidirectional_1 (Bidirectional) (None, 10, 1024)     2383872     concatenate[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 10, 256)      886272      bidirectional_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 10, 256)      65792       bidirectional_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 10, 256)      0           dense_2[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 10, 256)      0           activation_2[0][0]
#                                                                  bidirectional_2[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 256)          0           multiply_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 300)          77100       lambda_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 300)          0           dense_3[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 64)           19264       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 64)           0           dense_4[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 1)            65          dropout_1[0][0]
# ==================================================================================================
# Total params: 68,605,613
# Trainable params: 68,605,613
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
def parse_data(x):
    description = {'x1': tf.io.FixedLenFeature([], tf.string, default_value=''),
                   'x2': tf.io.FixedLenFeature([], tf.string, default_value=''),
                   'y': tf.io.FixedLenFeature([], tf.float32, default_value=-1)}
    parsed_features = tf.io.parse_single_example(x, description)
    x1 = tf.io.decode_raw(parsed_features['x1'], 'int64')
    x1 = tf.reshape(x1, [HyperParams.sequence_len, HyperParams.num_docs, HyperParams.num_words]) #
    # x1 = tf.cast(x1, tf.float32)

    x2 = tf.io.decode_raw(parsed_features['x2'], 'float32')
    x2 = tf.reshape(x2, [HyperParams.sequence_len, HyperParams.auxiliary_x])

    y = parsed_features['y']

    return x1, x2, y


def load_data(file):
    df = tf.data.TFRecordDataset(file)
    df = df.map(parse_data)
    return df


def get_train_data(train_fn, batch_size: int = HyperParams.batch_size):
    df = load_data(train_fn)
    df = df.repeat().shuffle(64).batch(batch_size).prefetch(HyperParams.auto_tune)
    return df


def get_valid_data(valid_fn, batch_size: int = HyperParams.batch_size):
    df = load_data(valid_fn)
    df = df.repeat().shuffle(64).batch(batch_size).prefetch(HyperParams.auto_tune)
    return df

# %%
df_train = get_train_data('/content/drive/MyDrive/2040 final/2040 final proj/pfizer_train.tfrecords')
df_validation = get_valid_data('/content/drive/MyDrive/2040 final/2040 final proj/pfizer_validation.tfrecords')

# %%
n_train = 5250

# %%
def train_generator(df):
    for i, j, k in df.as_numpy_iterator():
        yield ([i, j], k)

    
def validation_generator(df):
    for i, j, k in df.as_numpy_iterator():
        yield ([i, j], k)

# %%
tg = train_generator(df_train)
vg = validation_generator(df_validation)

# %%
history_m1 = m1.fit(tg, validation_data=vg, batch_size=HyperParams.batch_size, epochs=HyperParams.epochs, steps_per_epoch=n_train//HyperParams.batch_size, validation_steps=HyperParams.validation_steps, callbacks=[HyperParams.es, HyperParams.r])
m1.save_model('/content/drive/MyDrive/2040 final/2040 final proj/model_ver_1.h5')
save_obj(history_m1.history, '/content/drive/MyDrive/2040 final/2040 final proj/model_ver_1_hist')
# Out:
# Epoch 1/40
# 328/328 [==============================] - 390s 1s/step - loss: 0.4143 - mean_absolute_error: 0.5787 - mean_squared_error: 0.3586 - mean_squared_logarithmic_error: 0.2027 - val_loss: 0.0805 - val_mean_absolute_error: 0.1490 - val_mean_squared_error: 0.0249 - val_mean_squared_logarithmic_error: 0.0100
# Epoch 2/40
# 328/328 [==============================] - 359s 1s/step - loss: 0.0850 - mean_absolute_error: 0.1254 - mean_squared_error: 0.0295 - mean_squared_logarithmic_error: 0.0127 - val_loss: 0.0795 - val_mean_absolute_error: 0.1501 - val_mean_squared_error: 0.0243 - val_mean_squared_logarithmic_error: 0.0096
# Epoch 3/40
# 328/328 [==============================] - 359s 1s/step - loss: 0.0737 - mean_absolute_error: 0.0987 - mean_squared_error: 0.0186 - mean_squared_logarithmic_error: 0.0077 - val_loss: 0.0773 - val_mean_absolute_error: 0.1468 - val_mean_squared_error: 0.0224 - val_mean_squared_logarithmic_error: 0.0088
# Epoch 4/40
# 328/328 [==============================] - 357s 1s/step - loss: 0.0667 - mean_absolute_error: 0.0810 - mean_squared_error: 0.0120 - mean_squared_logarithmic_error: 0.0048 - val_loss: 0.0699 - val_mean_absolute_error: 0.1216 - val_mean_squared_error: 0.0155 - val_mean_squared_logarithmic_error: 0.0060
# Epoch 5/40
# 328/328 [==============================] - 358s 1s/step - loss: 0.0617 - mean_absolute_error: 0.0653 - mean_squared_error: 0.0074 - mean_squared_logarithmic_error: 0.0029 - val_loss: 0.0651 - val_mean_absolute_error: 0.1049 - val_mean_squared_error: 0.0112 - val_mean_squared_logarithmic_error: 0.0043
# Epoch 6/40
# 328/328 [==============================] - 357s 1s/step - loss: 0.0593 - mean_absolute_error: 0.0562 - mean_squared_error: 0.0055 - mean_squared_logarithmic_error: 0.0021 - val_loss: 0.0606 - val_mean_absolute_error: 0.0839 - val_mean_squared_error: 0.0071 - val_mean_squared_logarithmic_error: 0.0027
# Epoch 7/40
# 328/328 [==============================] - 359s 1s/step - loss: 0.0572 - mean_absolute_error: 0.0487 - mean_squared_error: 0.0039 - mean_squared_logarithmic_error: 0.0014 - val_loss: 0.0573 - val_mean_absolute_error: 0.0655 - val_mean_squared_error: 0.0044 - val_mean_squared_logarithmic_error: 0.0016
# Epoch 8/40
# 328/328 [==============================] - 356s 1s/step - loss: 0.0559 - mean_absolute_error: 0.0445 - mean_squared_error: 0.0032 - mean_squared_logarithmic_error: 0.0012 - val_loss: 0.0565 - val_mean_absolute_error: 0.0627 - val_mean_squared_error: 0.0042 - val_mean_squared_logarithmic_error: 0.0015
# Epoch 9/40
# 328/328 [==============================] - 360s 1s/step - loss: 0.0548 - mean_absolute_error: 0.0412 - mean_squared_error: 0.0027 - mean_squared_logarithmic_error: 9.8116e-04 - val_loss: 0.0549 - val_mean_absolute_error: 0.0545 - val_mean_squared_error: 0.0032 - val_mean_squared_logarithmic_error: 0.0012
# Epoch 10/40
# 328/328 [==============================] - 357s 1s/step - loss: 0.0538 - mean_absolute_error: 0.0385 - mean_squared_error: 0.0023 - mean_squared_logarithmic_error: 8.4874e-04 - val_loss: 0.0524 - val_mean_absolute_error: 0.0314 - val_mean_squared_error: 0.0015 - val_mean_squared_logarithmic_error: 5.4294e-04
# Epoch 11/40
# 328/328 [==============================] - 356s 1s/step - loss: 0.0529 - mean_absolute_error: 0.0367 - mean_squared_error: 0.0022 - mean_squared_logarithmic_error: 7.8483e-04 - val_loss: 0.0514 - val_mean_absolute_error: 0.0293 - val_mean_squared_error: 0.0012 - val_mean_squared_logarithmic_error: 4.5625e-04
# Epoch 12/40
# 328/328 [==============================] - 358s 1s/step - loss: 0.0520 - mean_absolute_error: 0.0359 - mean_squared_error: 0.0021 - mean_squared_logarithmic_error: 7.6518e-04 - val_loss: 0.0503 - val_mean_absolute_error: 0.0266 - val_mean_squared_error: 9.7963e-04 - val_mean_squared_logarithmic_error: 3.5752e-04
# Epoch 13/40
# 328/328 [==============================] - 356s 1s/step - loss: 0.0511 - mean_absolute_error: 0.0357 - mean_squared_error: 0.0021 - mean_squared_logarithmic_error: 7.4813e-04 - val_loss: 0.0491 - val_mean_absolute_error: 0.0238 - val_mean_squared_error: 6.9016e-04 - val_mean_squared_logarithmic_error: 2.5203e-04
# Epoch 14/40
# 328/328 [==============================] - 358s 1s/step - loss: 0.0502 - mean_absolute_error: 0.0355 - mean_squared_error: 0.0020 - mean_squared_logarithmic_error: 7.3639e-04 - val_loss: 0.0487 - val_mean_absolute_error: 0.0335 - val_mean_squared_error: 0.0012 - val_mean_squared_logarithmic_error: 4.4480e-04
# Epoch 15/40
# 328/328 [==============================] - 355s 1s/step - loss: 0.0493 - mean_absolute_error: 0.0353 - mean_squared_error: 0.0020 - mean_squared_logarithmic_error: 7.4308e-04 - val_loss: 0.0476 - val_mean_absolute_error: 0.0299 - val_mean_squared_error: 9.9808e-04 - val_mean_squared_logarithmic_error: 3.6348e-04
# Epoch 16/40
# 328/328 [==============================] - 356s 1s/step - loss: 0.0483 - mean_absolute_error: 0.0348 - mean_squared_error: 0.0020 - mean_squared_logarithmic_error: 7.1238e-04 - val_loss: 0.0472 - val_mean_absolute_error: 0.0375 - val_mean_squared_error: 0.0015 - val_mean_squared_logarithmic_error: 5.5942e-04
# Epoch 17/40
# 328/328 [==============================] - 358s 1s/step - loss: 0.0473 - mean_absolute_error: 0.0341 - mean_squared_error: 0.0019 - mean_squared_logarithmic_error: 6.8785e-04 - val_loss: 0.0466 - val_mean_absolute_error: 0.0432 - val_mean_squared_error: 0.0019 - val_mean_squared_logarithmic_error: 7.0378e-04
# Epoch 18/40
# 328/328 [==============================] - 356s 1s/step - loss: 0.0466 - mean_absolute_error: 0.0361 - mean_squared_error: 0.0021 - mean_squared_logarithmic_error: 7.6993e-04 - val_loss: 0.0451 - val_mean_absolute_error: 0.0360 - val_mean_squared_error: 0.0013 - val_mean_squared_logarithmic_error: 4.9456e-04
# Epoch 19/40
# 328/328 [==============================] - 358s 1s/step - loss: 0.0455 - mean_absolute_error: 0.0356 - mean_squared_error: 0.0020 - mean_squared_logarithmic_error: 7.3482e-04 - val_loss: 0.0446 - val_mean_absolute_error: 0.0383 - val_mean_squared_error: 0.0018 - val_mean_squared_logarithmic_error: 6.5856e-04
# Epoch 20/40
# 328/328 [==============================] - 360s 1s/step - loss: 0.0446 - mean_absolute_error: 0.0353 - mean_squared_error: 0.0020 - mean_squared_logarithmic_error: 7.1768e-04 - val_loss: 0.0441 - val_mean_absolute_error: 0.0438 - val_mean_squared_error: 0.0022 - val_mean_squared_logarithmic_error: 7.9482e-04
# Epoch 21/40
# 328/328 [==============================] - 359s 1s/step - loss: 0.0437 - mean_absolute_error: 0.0351 - mean_squared_error: 0.0020 - mean_squared_logarithmic_error: 7.2221e-04 - val_loss: 0.0426 - val_mean_absolute_error: 0.0378 - val_mean_squared_error: 0.0016 - val_mean_squared_logarithmic_error: 5.9229e-04
# Epoch 22/40
# 328/328 [==============================] - 356s 1s/step - loss: 0.0427 - mean_absolute_error: 0.0342 - mean_squared_error: 0.0019 - mean_squared_logarithmic_error: 6.9173e-04 - val_loss: 0.0424 - val_mean_absolute_error: 0.0457 - val_mean_squared_error: 0.0023 - val_mean_squared_logarithmic_error: 8.3005e-04
# Epoch 23/40
# 328/328 [==============================] - 358s 1s/step - loss: 0.0417 - mean_absolute_error: 0.0337 - mean_squared_error: 0.0018 - mean_squared_logarithmic_error: 6.6735e-04 - val_loss: 0.0424 - val_mean_absolute_error: 0.0550 - val_mean_squared_error: 0.0032 - val_mean_squared_logarithmic_error: 0.0012
# Epoch 24/40
#  42/328 [==>...........................] - ETA: 5:14 - loss: 0.0412 - mean_absolute_error: 0.0346 - mean_squared_error: 0.0020 - mean_squared_logarithmic_error: 7.2066e-04

# %%
# Out:
# array([[0.66498667],
#        [0.66498667],
#        [0.66498667],
#        [0.66498667],
#        [0.66498667],
#        [0.671855  ],
#        [0.66498667],
#        [0.671855  ]], dtype=float32)

# %%
m1_hist = load_obj('/content/drive/MyDrive/2040 final/2040 final proj/model_ver_1_hist')
import matplotlib.pyplot as plt
plt.plot(m1_hist['val_loss'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-3cf6fa99dac3> in <module>()
# ----> 1 m1_hist = load_obj('/content/drive/MyDrive/2040 final/2040 final proj/model_ver_1_hist')
#       2 import matplotlib.pyplot as plt
#       3 plt.plot(m1_hist['val_loss'])
#
# NameError: name 'load_obj' is not defined
